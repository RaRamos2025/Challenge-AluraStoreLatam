# %% [markdown]
# <a href="https://colab.research.google.com/github/RaRamos2025/Challenge-AluraStoreLatam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import matplotlib.pyplot as plt

#Calcula la facturación total por tienda
sumaTienda = sum(tienda['Precio'])
sumaTienda2 = sum(tienda2['Precio'])
sumaTienda3 = sum(tienda3['Precio'])
sumaTienda4 = sum(tienda4['Precio'])

#Imprime los resultados de la facturación total
print(f'INGRESOS TOTALES POR TIENDA\n')
print(f'Ingreso total de la tienda 1 es: ${sumaTienda:.0f}')
print(f'Ingreso total de la tienda 2 es: ${sumaTienda2:.0f}')
print(f'Ingreso total de la tienda 3 es: ${sumaTienda3:.0f}')
print(f'Ingreso total de la tienda 4 es: ${sumaTienda4:.0f}')
# Out:
# INGRESOS TOTALES POR TIENDA
#
# Ingreso total de la tienda 1 es: $1150880400
# Ingreso total de la tienda 2 es: $1116343500
# Ingreso total de la tienda 3 es: $1098019600
# Ingreso total de la tienda 4 es: $1038375700

# %%
import matplotlib.pyplot as plt

#Genera las listas para gráfico
tiendas = ['tienda', 'tienda2', 'tienda3', 'tienda4']
facturación = [sumaTienda, sumaTienda2, sumaTienda3, sumaTienda4]

#Gráfico de barras con facturación total por tienda
plt.bar(x=tiendas, height=facturación)
plt.title('Facturación por tienda')
plt.xlabel('Tienda')
plt.ylabel('Facturación')
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
import matplotlib.pyplot as plt

#Cantidad de productos por categoría por tienda
categorias_tienda = tienda.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
categorias_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
categorias_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
categorias_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)

#Imprime los resultados por categoría para cada tienda
print(f'Ventas por Categoría Tienda 1\n')
print(categorias_tienda)
print('\n')

print(f'Ventas por Categoría Tienda 2\n')
print(categorias_tienda2)
print('\n')

print(f'Ventas por Categoría Tienda 3\n')
print(categorias_tienda3)
print('\n')

print(f'Ventas por Categoría Tienda 4\n')
print(categorias_tienda4)
print('\n')
# Out:
# Ventas por Categoría Tienda 1
#
# Categoría del Producto
# Electrónicos               429493500.0
# Electrodomésticos          363685200.0
# Muebles                    187633700.0
# Instrumentos musicales      91299000.0
# Deportes y diversión        39290000.0
# Juguetes                    17995700.0
# Artículos para el hogar     12698400.0
# Libros                       8784900.0
# Name: Precio, dtype: float64
#
#
# Ventas por Categoría Tienda 2
#
# Categoría del Producto
# Electrónicos               410831100.0
# Electrodomésticos          348567800.0
# Muebles                    176426300.0
# Instrumentos musicales     104990300.0
# Deportes y diversión        34744500.0
# Juguetes                    15945400.0
# Artículos para el hogar     14746900.0
# Libros                      10091200.0
# Name: Precio, dtype: float64
#
#
# Ventas por Categoría Tienda 3
#
# Categoría del Producto
# Electrónicos               410775800.0
# Electrodomésticos          329237900.0
# ...

# %%
import matplotlib.pyplot as plt

#Genera gráfico de barras horizontales por categoría para cada tienda
plt.figure(figsize=(6, 2))
barras = plt.barh(categorias_tienda.index, categorias_tienda.values)
plt.title('Ventas por Categoría Tienda')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

plt.figure(figsize=(6, 2))
barras2 = plt.barh(categorias_tienda2.index, categorias_tienda2.values)
plt.title('Ventas por Categoría Tienda 2')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras2:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

plt.figure(figsize=(6, 2))
barras3 = plt.barh(categorias_tienda3.index, categorias_tienda3.values)
plt.title('Ventas por Categoría Tienda 3')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras3:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

plt.figure(figsize=(6, 2))
barras4 = plt.barh(categorias_tienda4.index, categorias_tienda4.values)
plt.title('Ventas por Categoría Tienda 4')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras4:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
#Denidición del promedio de calificaciones por tienda
calif_prom = tienda['Calificación'].mean()
calif_prom2 = tienda2['Calificación'].mean()
calif_prom3 = tienda3['Calificación'].mean()
calif_prom4 = tienda4['Calificación'].mean()

# Imprime los resultados de Promedio de calificaciones por tienda, considera
# resultados con 2 decimales
print (f'Calificación promedio de la tienda 1: {calif_prom:.2f}')
print (f'Calificación promedio de la tienda 2: {calif_prom2:.2f}')
print (f'Calificación promedio de la tienda 3: {calif_prom3:.2f}')
print (f'Calificación promedio de la tienda 4: {calif_prom4:.2f}')
# Out:
# Calificación promedio de la tienda 1: 3.98
# Calificación promedio de la tienda 2: 4.04
# Calificación promedio de la tienda 3: 4.05
# Calificación promedio de la tienda 4: 4.00

# %%
#Genera gráfico de puntos con las calificaciones promedio de cada tienda
tiendas = ['tienda', 'tienda2', 'tienda3', 'tienda4']
promedios = [calif_prom, calif_prom2, calif_prom3, calif_prom4]
puntos = plt.scatter(tiendas, promedios)
plt.title('Calificación promedio por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Calificación Promedio')
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
#Define lista de productos más y menos vendidos para la tienda 1
ventas_producto = tienda.groupby('Producto')['Precio'].count().sort_values(ascending=False)
mas_vendidos1 = ventas_producto.head(5)
menos_vendidos1 = ventas_producto.tail(5)
print(f"\nTienda 1 - Productos más vendidos:")
print(mas_vendidos1)
print(f"\nTienda 1 - Productos menos vendidos:")
print(menos_vendidos1)

#Define lista de productos más y menos vendidos para la tienda 2
ventas_producto = tienda2.groupby('Producto')['Precio'].count().sort_values(ascending=False)
mas_vendidos2 = ventas_producto.head(5)
menos_vendidos2 = ventas_producto.tail(5)
print(f"\nTienda 2 - Productos más vendidos:")
print(mas_vendidos2)
print(f"\nTienda 2 - Productos menos vendidos:")
print(menos_vendidos2)

#Define lista de productos más y menos vendidos para la tienda 3
ventas_producto = tienda3.groupby('Producto')['Precio'].count().sort_values(ascending=False)
mas_vendidos3 = ventas_producto.head(5)
menos_vendidos3 = ventas_producto.tail(5)
print(f"\nTienda 3 - Productos más vendidos:")
print(mas_vendidos3)
print(f"\nTienda 3 - Productos menos vendidos:")
print(menos_vendidos3)

#Define lista de productos más y menos vendidos para la tienda 4
ventas_producto = tienda4.groupby('Producto')['Precio'].count().sort_values(ascending=False)
mas_vendidos4 = ventas_producto.head(5)
menos_vendidos4 = ventas_producto.tail(5)
print(f"\nTienda 4 - Productos más vendidos:")
print(mas_vendidos4)
print(f"\nTienda 4 - Productos menos vendidos:")
print(menos_vendidos4)
# Out:
# Tienda 1 - Productos más vendidos:
# Producto
# Armario             60
# TV LED UHD 4K       60
# Microondas          60
# Secadora de ropa    58
# Mesa de noche       56
# Name: Precio, dtype: int64
#
# Tienda 1 - Productos menos vendidos:
# Producto
# Mochila                      39
# Pandereta                    36
# Olla de presión              35
# Celular ABXY                 33
# Auriculares con micrófono    33
# Name: Precio, dtype: int64
#
# Tienda 2 - Productos más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Pandereta                    58
# Guitarra acústica            58
# Name: Precio, dtype: int64
#
# Tienda 2 - Productos menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Impresora          34
# Mesa de comedor    34
# Juego de mesa      32
# Name: Precio, dtype: int64
#
# Tienda 3 - Productos más vendidos:
# Producto
# Kit de bancas      57
# ...

# %%
import matplotlib.pyplot as plt

#Genera gráfico de barras horizontales para mayores y menores ventas de tienda 1
plt.figure(figsize=(6, 2))
barras = plt.barh(mas_vendidos1.index, mas_vendidos1.values, color = 'green')
plt.title('Productos más vendidos tienda 1')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)
plt.figure(figsize=(6, 2))
barras = plt.barh(menos_vendidos1.index, menos_vendidos1.values, color = 'red')
plt.title('Productos menos vendidos tienda 1')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

#Genera gráfico de barras horizontales para mayores y menores ventas de tienda 2
plt.figure(figsize=(6, 2))
barras = plt.barh(mas_vendidos2.index, mas_vendidos2.values, color = 'green')
plt.title('Productos más vendidos tienda 2')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)
plt.figure(figsize=(6, 2))
barras = plt.barh(menos_vendidos2.index, menos_vendidos2.values, color = 'red')
plt.title('Productos menos vendidos tienda 2')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

#Genera gráfico de barras horizontales para mayores y menores ventas de tienda 3
plt.figure(figsize=(6, 2))
barras = plt.barh(mas_vendidos3.index, mas_vendidos3.values, color = 'green')
plt.title('Productos más vendidos tienda 3')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)
plt.figure(figsize=(6, 2))
barras = plt.barh(menos_vendidos3.index, menos_vendidos3.values, color = 'red')
plt.title('Productos menos vendidos tienda 3')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

#Genera gráfico de barras horizontales para mayores y menores ventas de tienda 4
plt.figure(figsize=(6, 2))
barras = plt.barh(mas_vendidos4.index, mas_vendidos4.values, color = 'green')
plt.title('Productos más vendidos tienda 4')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)
plt.figure(figsize=(6, 2))
barras = plt.barh(menos_vendidos4.index, menos_vendidos4.values, color = 'red')
plt.title('Productos menos vendidos tienda 4')
plt.xlabel('Ventas Totales')
plt.ylabel('Categoría')
plt.gca().invert_yaxis()
for barra in barras:
    valorx = barra.get_width()
    plt.text(valorx, barra.get_y() + barra.get_height()/2, f"{valorx:,.0f}", va='center', fontsize=8)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import matplotlib.pyplot as plt

#Realiza cálculo de valor de envío promedio por tienda
enviotienda = tienda['Costo de envío'].mean()
enviotienda2 = tienda2['Costo de envío'].mean()
enviotienda3 = tienda3['Costo de envío'].mean()
enviotienda4 = tienda4['Costo de envío'].mean()

#Imprime resultado de cálculo del valor promedio de envío por tienda
print(f'Costo de envío de la tienda 1: ${enviotienda:.2f}')
print(f'Costo de envío de la tienda 2: ${enviotienda2:.2f}')
print(f'Costo de envío de la tienda 3: ${enviotienda3:.2f}')
print(f'Costo de envío de la tienda 4: ${enviotienda4:.2f}')
# Out:
# Costo de envío de la tienda 1: $26018.61
# Costo de envío de la tienda 2: $25216.24
# Costo de envío de la tienda 3: $24805.68
# Costo de envío de la tienda 4: $23459.46

# %%
import matplotlib.pyplot as plt

#Genera las listas para gráfico
tiendas = ['tienda', 'tienda2', 'tienda3', 'tienda4']
envios = [enviotienda, enviotienda2, enviotienda3, enviotienda4]

#Gráfico de barras con costo de envío por tienda
plt.bar(x=tiendas, height=facturación)
plt.title('Costo de envío por tienda')
plt.xlabel('Tienda')
plt.ylabel('Costo envío')
plt.show()

# %% [markdown]
# ________________________________________________________________________

# %% [markdown]
# #INFORME ANÁLISIS DE DATOS ALURASTORE

# %% [markdown]
# ##Introducción
#
# El presente informe tiene por objetivo el análisis de ventas y rendimiento de 4 tiendas pertenecientes a Don Juan, con el objeto de ayudarlo a decidir qué tienda vender para invertir en un nuevo negocio. Para esto, evaluaremos cuál de estas cuatro tiendas tiene un desempeño menor, permitiendo al señor Juan tomar la decisión de cuál de estas cuatro tiendas debe vender para invertir en un nuevo negocio.<br>
# Los aspectos considerados para la toma de desición son los siguientes:<br>
#
# * Análisis de facturación
# * Ventas por categoría
# * Calificación promedio de la tienda
# * Productos más y menos vendidos
# * Envío promedio por tienda
#
# Los resultados obtenidos se presentan a continuación.

# %% [markdown]
# ##Desarrollo

# %% [markdown]
# ###1. Análisis de facturación
#
# Se calcula el ingreso total a partir de la suma de todos los productos vendidos por tienda:
#
# **Tienda 1:**  $1.150.880.400
#
# **Tienda 2:**  $1.116.343.500
#
# **Tienda 3:**  $1.098.019.600
#
# **Tienda 4:**  $1.038.375.700
#
# ![image.png](data:image/png;base64,...)
#
# La tienda que más factura corresponde a la **Tienda 1**, demostrando un buen volumen de ventas.
#
# Por el contrario la tienda que menos factura es la **Tienda 2** lo que demuestra debilidad en los aspectos mencionados.

# %% [markdown]
# ###2. Ventas por categoría
#
# Considerando las ventas de cada tienda por categoría, tenemos:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# En general se puede apreciar que las categorías más demandadas para todas las tiendas son: electrónicos, electrodomésticos y muebles.
#
# Además, para la mayoría de las categorías, la Tienda 4 presenta ventas menores al resto de las tiendas.

# %% [markdown]
# ###3. Calificación promedio de la tienda
#
# Respecto de la calificación promedio por tienda tenemos:
#
# * Calificación promedio de la tienda 1:   3.98
#
# * Calificación promedio de la tienda 2:   4.04
#
# * Calificación promedio de la tienda 3:   4.05
#
# * Calificación promedio de la tienda 4:   4.00
#
# La **Tienda 3** presenta la calificación más alta.
#
# Se aprecia la calificación más baja para la **Tienda 1**, seguida muy de cerca por la **Tienda 4**.

# %% [markdown]
# ###4. Productos más y menos vendidos
#
# Tienda 1 - Productos más vendidos:
#
# Producto | Cantidad
# ---|---
# Armario|60
# TV LED UHD 4K|60
# Microondas|60
# Secadora de ropa|58
# Mesa de noche|56
#
# Tienda 1 - Productos menos vendidos:
#
# Producto | Cantidad
# ---|---
# Mochila|39
# Pandereta|36
# Olla de presión|35
# Celular ABXY|33
# Auriculares con micrófono|33
#
# Tienda 2 - Productos más vendidos:
#
# Producto | Cantidad
# ---|---
# Iniciando en programación|65
# Microondas|62
# Batería|61
# Pandereta|58
# Guitarra acústica|58
#
# Tienda 2 - Productos menos vendidos:
#
# Producto | Cantidad
# ---|---
# Auriculares|37
# Sillón|35
# Impresora|34
# Mesa de comedor|34
# Juego de mesa|32
#
# Tienda 3 - Productos más vendidos:
#
# Producto | Cantidad
# ---|---
# Kit de bancas|      57
# Mesa de comedor|    56
# Cama king|          56
# Set de ollas|       55
# Mesa de noche|      55
#
# Tienda 3 - Productos menos vendidos:
#
# Producto | Cantidad
# ---|---
# Guitarra eléctrica|         38
# Mochila|                    36
# Microondas|                 36
# Set de vasos|               36
# Bloques de construcción|    35
#
# Tienda 4 - Productos más vendidos:
#
# Producto | Cantidad
# ---|---
# Cama box|                     62
# Cubertería|                   59
# Cama king|                    56
# Dashboards con Power BI|      56
# Carrito de control remoto|    55
#
# Tienda 4 - Productos menos vendidos:
#
# Producto | Cantidad
# ---|---
# Ciencia de datos con Python|    38
# Refrigerador|                   38
# Guitarra acústica|              37
# Armario|                        34
# Guitarra eléctrica|             33
#
# Respecto de los productos más y menos vendidos, se puede apreciar que ambos límites se encuentran dentro de los productos de la **Tienda 2**, donde el producto más vendido corresponde a Iniciando en programación con 65 ventas, y el producto menos vendido es juego de mesa con 32 unidades.

# %% [markdown]
# ###5. Envío promedio por tienda

# %% [markdown]
# ##Conclusión
